# %%
import matplotlib.pyplot as plt

flu2019 = [3538, 14780, 50526, 101242, 88851, 37282]
flu2020 = [305, 319, 575, 361, 216, 149]

fig, ax = plt.subplots()
ax.plot(['Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar'], flu2019)

ax.set(xlabel='Month', ylabel='Flu Cases',
       title='America 2019 Flu Cases')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(['Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar'], flu2020)

ax.set(xlabel='Month', ylabel='Flu Cases',
       title='America 2020 Flu Cases')
ax.grid()

fig.savefig("test.png")
plt.show()
